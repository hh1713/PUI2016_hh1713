# %%
from __future__ import print_function
__author__= 'fbb'
import numpy as np
import pylab as pl

from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Chi-squared distribution

# %%
distributions = ['chisq']

# %%
mymean = 100
df = mymean
mystd = np.sqrt(2*mymean) 
# my standard deviation (variance is 2*mean). I chose to have the same std 
# for all distributions (where applicable)

# %%
md = {}

md['chisq'] = np.random.chisquare(df, size=100)

pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('All the means from 100 observations')

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 101.23, standard deviation: 13.58

# %%
mysize = (2000.0 / (np.array(range(1, 101)))).astype(float)

# %%
md['chisq'] = {}

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Means from all observations")

# %% [markdown]
# # Normal distribution - Gaussian distribution

# %%
distributions = ['gaus']

# %%
md['gaus'] = np.random.normal(mymean, mystd, size=100)

pl.hist(md['gaus'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('All the means from 100 observations')

# %%
print ("Gaus mean: %.2f, standard deviation: %.2f"%(md['gaus'].mean(), md['gaus'].std()))
# Out:
# Gaus mean: 100.51, standard deviation: 12.02

# %%
md['gaus'] = {} 

for n in mysize:
    md['gaus'][n] = np.random.normal(mymean, mystd, size = n) #what should std be?
    

md['gaus']['means'] = {}
axgaus_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['gaus']:
    if not type(nn) == str:
        md['gaus']['means'][nn] = md['gaus'][nn].mean()
        #and plot it
        axgaus_mu_n.plot(nn, md['gaus']['means'][nn], 'o')
        axgaus_mu_n.set_xlabel('sample size', fontsize=18)
        axgaus_mu_n.set_ylabel('sample mean', fontsize=18)
        axgaus_mu_n.set_title('Gaussian distribution', fontsize=18)
        axgaus_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
allmeans = list(md['gaus']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Means from all observations")

# %% [markdown]
# # Poisson distribution

# %%
distributions = ['pois']

# %%
md['pois'] = np.random.poisson(mymean, size=100)

pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('All the means from 100 observations')

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Poisson mean: 99.18, standard deviation: 10.09

# %%
md['pois'] = {} 

for n in mysize:
    md['pois'][n] = np.random.poisson(mymean, size=n)
    

md['pois']['means'] = {}
axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('Poisson distribution', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Means from all observations")

# %% [markdown]
# # Binomial distribution

# %%
distributions = ['binomial']

# %%
md['binomial'] = np.random.binomial(1000, 0.1, size=100)

pl.hist(md['binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('All the means from 100 observations')

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binomial'].mean(), md['binomial'].std()))
# Out:
# Binomial mean: 100.30, standard deviation: 9.12

# %%
md['binomial'] = {} 

for n in mysize:
    md['binomial'][n] = np.random.binomial(1000, 0.1, size=n)
    

md['binomial']['means'] = {}
axbinomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binomial']:
    if not type(nn) == str:
        md['binomial']['means'][nn] = md['binomial'][nn].mean()
        #and plot it
        axbinomial_mu_n.plot(nn, md['binomial']['means'][nn], 'o')
        axbinomial_mu_n.set_xlabel('sample size', fontsize=18)
        axbinomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinomial_mu_n.set_title('Binomial distribution', fontsize=18)
        axbinomial_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
allmeans = list(md['binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Means from all observations")

# %% [markdown]
# # Negative-binomial distributions

# %%
distributions = ['neg_binomial']

# %%
md['neg_binomial'] = np.random.negative_binomial(900, 0.9, size=100)

pl.hist(md['neg_binomial'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('All the means from 100 observations')

# %%
print ("negative binomial mean: %.2f, standard deviation: %.2f"%(md['neg_binomial'].mean(), md['neg_binomial'].std()))
# Out:
# negative binomial mean: 98.32, standard deviation: 10.02

# %%
md['neg_binomial'] = {} 

for n in mysize:
    md['neg_binomial'][n] = np.random.negative_binomial(900, 0.9, size=n)
    

md['neg_binomial']['means'] = {}
axneg_binomial_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['neg_binomial']:
    if not type(nn) == str:
        md['neg_binomial']['means'][nn] = md['neg_binomial'][nn].mean()
        #and plot it
        axneg_binomial_mu_n.plot(nn, md['neg_binomial']['means'][nn], 'o')
        axneg_binomial_mu_n.set_xlabel('sample size', fontsize=18)
        axneg_binomial_mu_n.set_ylabel('sample mean', fontsize=18)
        axneg_binomial_mu_n.set_title('Negative binomial distribution', fontsize=18)
        axneg_binomial_mu_n.plot([min(mysize), max(mysize)], [mymean, mymean], 'k')
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
allmeans = list(md['neg_binomial']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Means from all observations")

# %% [markdown]
# # Describe the behavior you see in the plots in terms of the law of large numbers
#
# ### For all the distributions plotted, the variance of the sample means gets smaller as the sample size grows larger, thus edging closer to the declared value of mymean = 100.

# %% [markdown]
# # Plot all the means the distributions of all sample means as a histogram

# %%
new_list = []

for i in md.keys():
    for nn in md[i]:
        if not type(nn) == str:
            new_list.append(md[i][nn].mean())
            
pl.figure(figsize=(10, 10))

mean = np.mean(new_list)
variance = np.var(new_list)
sigma = np.sqrt(variance)
x = np.linspace(min(new_list), max(new_list),100)
pl.plot(x,mlab.normpdf(x,mean,sigma))

pl.hist(new_list,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title("Frequency of means from all 500 observations")
